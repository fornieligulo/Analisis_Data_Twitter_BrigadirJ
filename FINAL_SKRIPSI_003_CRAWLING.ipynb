# %% [markdown]
# <a href="https://colab.research.google.com/github/fornieligulo/Analisis_Data_Twitter_BrigadirJ/blob/main/FINAL_SKRIPSI_003_CRAWLING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***CRAWLING DATA TWITTER***

# %%
# Install Library tweet
# !pip install tweepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Import Library
import tweepy
import pandas as pd
import numpy as np

# Isi API Key Twitter
API_key = 'x9KXRVQGAeuxPUjGZ3engtfBb'
API_secret = 'RTwnJjjWfLCwtQcktmNuw1Q1HyHzC68Z5N0mKEKSN1Qgo5mzOF'
access_token = '1430515782245490690-lBcjpRbtPVheumbzSuxjVclmQaNMjp'
access_token_secret = 'iaDTgheJbvhZQXApvIih7BGSY9bhASqlNNtP0Yn7EeYts'

# Autentikkasi API Key Twitter
auth = tweepy.OAuthHandler(API_key, API_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# Menemukan tweet berdasarkan (Kata Kunci, Jumlah, Bahasa) 
tweets = api.search_tweets('sambo', count=200, lang='id')

# Tampilkan Tweets
tweets

# Cetak tweet yang dikumpulkan
data = pd.DataFrame()
data['Created At'] = [tweet.created_at for tweet in tweets]
data['Screen Name'] = [tweet.user.screen_name for tweet in tweets]
data['tweets'] = [tweet.text for tweet in tweets]
data['Location'] = [tweet.user.location for tweet in tweets]
data['Number of Retweet'] = [tweet.retweet_count for tweet in tweets]
data['Number of Like'] = [tweet.favorite_count for tweet in tweets]
display(data.head(20))

# Save as .CSV
data.to_csv('dataSambo.csv')
# Out:
#                   Created At      Screen Name  \
# 0  2023-05-18 10:28:40+00:00    Ilyas55120860
# 1  2023-05-18 10:28:21+00:00        heffheven
# 2  2023-05-18 10:21:44+00:00         byeorida
# 3  2023-05-18 10:20:54+00:00        kamaloeby
# 4  2023-05-18 10:14:04+00:00   sugarcandyblue
# 5  2023-05-18 10:11:11+00:00     alin_raihani
# 6  2023-05-18 10:09:28+00:00       abimandaru
# 7  2023-05-18 10:08:06+00:00          hoobaei
# 8  2023-05-18 10:07:16+00:00    alfajri221810
# 9  2023-05-18 09:57:01+00:00       AndiBoga06
# 10 2023-05-18 09:56:37+00:00    Lindiwe_Sambo
# 11 2023-05-18 09:51:42+00:00          asykadi
# 12 2023-05-18 09:48:34+00:00   neverlandalien
# 13 2023-05-18 09:37:22+00:00    alfajri221810
# 14 2023-05-18 09:36:31+00:00      putra_adrin
# 15 2023-05-18 09:29:02+00:00    Lindiwe_Sambo
# 16 2023-05-18 09:26:26+00:00       MSikakulya
# 17 2023-05-18 09:20:37+00:00       silumanTai
# 18 2023-05-18 09:19:29+00:00  bagusal04043501
# ...
